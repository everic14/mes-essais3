# %%
https://gitlab.com/brohrer/study-time-tools.t

cd study-time-tools
# Out:
#   File "<ipython-input-2-cf7b4b88c5cb>", line 1
#     https://gitlab.com/brohrer/study-time-tools.t
#           ^
# SyntaxError: invalid syntax
